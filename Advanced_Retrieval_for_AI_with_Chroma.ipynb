# %% [markdown]
# <a href="https://colab.research.google.com/github/Julianhm9612/deeplearning-ai/blob/main/Advanced_Retrieval_for_AI_with_Chroma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
